# %% [markdown]
# # CNN regression

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %matplotlib inline
mpl.style.use('bmh')

# %%
import ujson

from sorder.metrics import Metrics

# %%
with open('cnn.json') as fh:
    metrics = Metrics(ujson.load(fh))

# %%
len(metrics.gold_pred)
# Out:
# 110615

# %% [markdown]
# # Perfect order

# %%
metrics.overall_perfect_order_pct()
# Out:
# 0.2687700583103557

# %%
xy = metrics.perfect_order_pct_by_len()

x, y = zip(*xy.items())

plt.ylim(-0.05, 1)
plt.xticks(x)
plt.xlabel('Sentence length')
plt.ylabel('Percentage correct')
plt.plot(x, y)

# %% [markdown]
# # Kendall's tau

# %%
metrics.overall_kt()
# Out:
# 0.60304982406061214

# %%
xy = metrics.avg_kt_by_len()

x, y = zip(*xy.items())

plt.ylim(-0.05, 1)
plt.xticks(x)
plt.xlabel('Sentence length')
plt.ylabel('Percentage correct')
plt.plot(x, y)

# %% [markdown]
# # Positional accuracy

# %%
metrics.overall_positional_accuracy_pct()
# Out:
# 0.42787437092892128

# %%
xy = metrics.positional_accuracy_pct_by_len()

x, y = zip(*xy.items())

plt.ylim(-0.05, 1)
plt.xticks(x)
plt.xlabel('Sentence length')
plt.ylabel('Percentage correct')
plt.plot(x, y)
