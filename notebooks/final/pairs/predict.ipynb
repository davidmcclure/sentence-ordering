# %% [markdown]
# # Pair prediction (Chen et al.)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %matplotlib inline
mpl.style.use('bmh')

# %%
import ujson

from sent_order.metrics import Metrics

# %%
with open('gp.360.json') as fh:
    metrics = Metrics(ujson.load(fh))

# %% [markdown]
# # Perfect order

# %%
metrics.overall_perfect_order_pct()
# Out:
# 0.3223762376237624

# %%
xy = metrics.perfect_order_pct_by_len()

x, y = zip(*xy.items())

plt.ylim(-0.05, 1)
plt.xticks(x)
plt.xlabel('Sentence length')
plt.ylabel('Percentage correct')
plt.plot(x, y)

# %% [markdown]
# # Kendall's tau

# %%
metrics.overall_kt()
# Out:
# 0.54440057144217535

# %%
xy = metrics.avg_kt_by_len()

x, y = zip(*xy.items())

plt.ylim(-0.05, 1)
plt.xticks(x)
plt.xlabel('Sentence length')
plt.ylabel('Percentage correct')
plt.plot(x, y)

# %% [markdown]
# # Positional accuracy

# %%
metrics.overall_positional_accuracy_pct()
# Out:
# 0.40775776987393159

# %%
xy = metrics.positional_accuracy_pct_by_len()

x, y = zip(*xy.items())

plt.ylim(-0.05, 1)
plt.xticks(x)
plt.xlabel('Sentence length')
plt.ylabel('Percentage correct')
plt.plot(x, y)
