# %% [markdown]
# # Regression with paragraph context

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %matplotlib inline
mpl.style.use('bmh')

# %%
import ujson

from sent_order.metrics import Metrics

# %%
with open('gp.205.json') as fh:
    metrics = Metrics(ujson.load(fh))

# %% [markdown]
# # Perfect order

# %%
metrics.overall_perfect_order_pct()
# Out:
# 0.3620937485874429

# %%
xy = metrics.perfect_order_pct_by_len()

x, y = zip(*xy.items())

plt.ylim(-0.05, 1)
plt.xticks(x)
plt.xlabel('Sentence length')
plt.ylabel('Percentage correct')
plt.plot(x, y)

# %% [markdown]
# # Kendall's tau

# %%
metrics.overall_kt()
# Out:
# 0.71444853209349957

# %%
xy = metrics.avg_kt_by_len()

x, y = zip(*xy.items())

plt.ylim(-0.05, 1)
plt.xticks(x)
plt.xlabel('Sentence length')
plt.ylabel('Percentage correct')
plt.plot(x, y)

# %% [markdown]
# # Positional accuracy

# %%
metrics.overall_positional_accuracy_pct()
# Out:
# 0.52727012606668577

# %%
xy = metrics.positional_accuracy_pct_by_len()

x, y = zip(*xy.items())

plt.ylim(-0.05, 1)
plt.xticks(x)
plt.xlabel('Sentence length')
plt.ylabel('Percentage correct')
plt.plot(x, y)
