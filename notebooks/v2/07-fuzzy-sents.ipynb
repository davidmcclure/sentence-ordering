# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %matplotlib inline
mpl.style.use('bmh')

# %%
import torch
import attr
import pandas as pd

from textblob import TextBlob
from cached_property import cached_property
from annoy import AnnoyIndex
from itertools import combinations
from tqdm import tqdm_notebook
from scipy.spatial.distance import cosine

from sent_order.models.kt_regression import Sentence, SentenceEncoder

# %%
sent_encoder = torch.load(
    '../../data/models/new/kt-reg/sent_encoder.366.bin',
    map_location={'cuda:0': 'cpu'},
)

# %%
@attr.s
class Text:

    raw = attr.ib()
    
    @classmethod
    def from_path(cls, path):
        with open(path) as fh:
            return cls(fh.read())
    
    @cached_property
    def blob(self):
        return TextBlob(self.raw)
    
    def sentence_variables(self):
        for sent in self.blob.sentences:
            sent = Sentence(list(sent.tokens))
            yield sent.variable()

# %%
gg = Text.from_path('../../data/novels/great-gatsby.txt')

# %%
gg_sents = sent_encoder(gg.sentence_variables())

# %%
sar = Text.from_path('../../data/novels/sun-also-rises.txt')

# %%
sar_sents = sent_encoder(sar.sentence_variables())

# %%
gg_idx = AnnoyIndex(1000)

# %%
for i in range(len(gg_sents)):
    gg_idx.add_item(i, gg_sents[i].data.tolist())

# %%
gg_idx.build(10)
# Out:
# True

# %%
gg_idx.get_nns_by_vector(gg_sents[160].data.tolist(), 10, include_distances=True)
# Out:
# ([160, 2540, 915, 2322, 2548, 1342, 1613, 1213, 378, 1507],
#  [0.0,
#   1.1178419589996338,
#   1.1187474727630615,
#   1.118809700012207,
#   1.1280927658081055,
#   1.1366569995880127,
#   1.1381558179855347,
#   1.138733983039856,
#   1.143604040145874,
#   1.1484378576278687])

# %%
gg.blob.sentences[160]
# Out:
# Sentence("As if his absence quickened something within her, Daisy leaned forward again, her voice glowing and singing.")

# %%
gg.blob.sentences[610]
# Out:
# Sentence("I was in the ninth machine-gun battalion.”
#
# “I was in the Seventh Infantry until June nineteen-eighteen.")

# %%
matches = []
for sar_id in tqdm_notebook(range(len(sar_sents))):
    gg_ids, ds = gg_idx.get_nns_by_vector(sar_sents[sar_id].data.tolist(), 10, include_distances=True)
    for gg_id, d in zip(gg_ids, ds):
        if d > 0:
            matches.append((sar_id, gg_id, d))
# Out:
# HBox(children=(IntProgress(value=0, max=7579), HTML(value='')))

# %%
df = pd.DataFrame(matches, columns=('sar_id', 'gg_id', 'd'))

# %%
df.sort_values('d').head(1000)
# Out:
#        sar_id  gg_id         d
# 30732    3102   1857  0.504626
# 43876    4417    318  0.590269
# 54133    5446   1685  0.601002
# 14204    1443   1956  0.602994
# 41486    4178   2571  0.608421
# 55383    5571   1991  0.617864
# 67023    6742    318  0.633026
# 31062    3135   1109  0.635736
# 64833    6520   2459  0.640016
# 74733    7513    198  0.642554
# 54763    5509   1625  0.647011
# 13368    1347   1651  0.647925
# 17241    1747   2459  0.652234
# 18141    1837   1956  0.656966
# 9573      967   1625  0.658170
# 50804    5113   1651  0.661898
# 68963    6936   1651  0.661898
# 4985      508   2097  0.662738
# 64834    6520   2167  0.664344
# 19001    1923   2239  0.665362
# 20741    2097   1812  0.668192
# 23957    2424   2572  0.679352
# 42296    4259    533  0.679385
# 36019    3631   1956  0.679604
# 41066    4136   1956  0.679604
# 7313      741   1956  0.679604
# 13118    1322   1956  0.679604
# 4775      487   1956  0.679604
# 21769    2200   1956  0.679604
# 46056    4638   1956  0.679604
# ...       ...    ...       ...
# 35309    3560     77  0.845916
# 60343    6069   2351  0.845968
# 36179    3647   2490  0.845981
# 223        31   2167  0.846043
# 4857      495   1174  0.846049
# 8143      824   2516  0.846101
# 62986    6335   2167  0.846123
# 55686    5601    151  0.846232
# 66215    6661     77  0.846297
# 64603    6497    955  0.846308
# 35369    3566    866  0.846311
# 58034    5836    737  0.846382
# 61093    6144   1812  0.846509
# 50335    5066     86  0.846544
# 20913    2114   1812  0.846801
# 45208    4553   1898  0.846801
# 32915    3320   1976  0.846813
# 8673      877   2472  0.846819
# 41490    4178    198  0.846844
# 27277    2756   1532  0.846960
# 31302    3159   1353  0.846968
# 10586    1068    151  0.847058
# 7543      764    969  0.847059
# 39056    3935   1621  0.847104
# 51755    5208   1697  0.847147
# 61203    6155   1345  0.847196
# 64614    6498   1810  0.847361
# 59874    6022    866  0.847427
# 24917    2520   2201  0.847450
# 32052    3234   2493  0.847496
#
# [1000 rows x 3 columns]

# %%
for r in df.sort_values('d').head(100).itertuples():
    print(sar.blob.sentences[r.sar_id], '|', gg.blob.sentences[r.gg_id])
    print('---')
# Out:
# “Come on, Michael. | “Come on, Tom.
# ---
# What do you think of that?”
#
# “I don’t know.”
#
# “That’s it. | What kind do you want, lady?”
#
# “I’d like to get one of those police dogs; I don’t suppose you got that kind?”
#
# The man peered doubtfully into the basket, plunged in his hand and drew one up, wriggling, by the back of the neck.
# ---
# That was it all right. | That was it.
# ---
# “Really?”
#
# “No. | “What?”
#
# “Want any?”
#
# “No .
# ---
# Do you care?”
#
# “No,” Edna said. | Do you object to shaking hands with me?”
#
# “Yes.
# ---
# “It’s good. | “That’s good.
# ---
# What do you think of that?”
#
# “I don’t know.”
#
# “That’s the way. | What kind do you want, lady?”
#
# “I’d like to get one of those police dogs; I don’t suppose you got that kind?”
#
# The man peered doubtfully into the basket, plunged in his hand and drew one up, wriggling, by the back of the neck.
# ---
# They’re all right.”
#
# “How did your friends like them?”
#
# “Fine.”
#
# “Good,” Montoya said. | They’re fine!” and he added hollowly, “.
# ---
# He was fairly happy, except that he would rather have been in America, and he discovered writing. | He was so hard up he had to keep on wearing his uniform because he couldn’t buy some regular clothes.
# ---
# Would you buy a lady a drink?”
#
# “We’ll have two more martinis.”
#
# “Right you are Sir. | Would you like to hear?”
#
# “Very much.”
#
# “It’ll show you how I’ve gotten to feel about—things.
# ---
# I don’t think I hurt him any.”
#
# “You were probably damn good for him.”
#
# “He shouldn’t be living with any one. | I don’t think he had ever really believed in its existence before.
# ---
# Let’s get out of this.”
#
# “Have another brandy,” the count said. | Let’s all go to town!”
#
# Her voice struggled on through the heat, beating against it, molding its senselessness into forms.
# ---
# He was having a very quiet time, he said, bathing, playing some golf and much bridge. | He was so hard up he had to keep on wearing his uniform because he couldn’t buy some regular clothes.
# ---
# “He’s from Chicago.”
#
# “You both going to Biarritz?”
#
# “No. | “What?”
#
# “Want any?”
#
# “No .
# ---
